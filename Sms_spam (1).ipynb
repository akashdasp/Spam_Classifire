# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# pd.read_csv("spam.csv")

# %%
df = pd.read_csv("spam.csv",encoding='latin-1')

# %%
df
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %%
df.shape
# Out:
# (5572, 5)

# %% [markdown]
# #   <u>   Content </u>
# - Data Cleaning
# - EDA
# - Text Preprocessing
# - Model building
# - Evaluation
# - Improvment
# - Website
# - Deployment

# %% [markdown]
# # Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df.drop(columns=["Unnamed: 2","Unnamed: 3","Unnamed: 4"],inplace=True)

# %%
df.rename(columns={"v1":"target","v2":"text"},inplace=True)

# %%
df
# Out:
#      target                                               text
# 0       ham  Go until jurong point, crazy.. Available only ...
# 1       ham                      Ok lar... Joking wif u oni...
# 2      spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       ham  U dun say so early hor... U c already then say...
# 4       ham  Nah I don't think he goes to usf, he lives aro...
# ...     ...                                                ...
# 5567   spam  This is the 2nd time we have tried 2 contact u...
# 5568    ham              Will Ì_ b going to esplanade fr home?
# 5569    ham  Pity, * was in mood for that. So...any other s...
# 5570    ham  The guy did some bitching but I acted like i'd...
# 5571    ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
encoder.fit(df["target"])
# Out:
# LabelEncoder()

# %%
df.target=encoder.transform(df["target"])

# %%
# missing Value Checking
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 403

# %%
df=df.drop_duplicates(keep="first")

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# # 2  EDA

# %%
plt.figure(figsize=(10,10))
plt.title(" The Data is Imbalanced")
plt.pie((df.target.value_counts()/df.shape[0])*100,autopct="%d",labels=["ham","spam"])
plt.show()

# %%
import nltk

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
df['num_characters']=df["text"].apply(len)
# Out:
# <ipython-input-20-628baca64ac4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_characters']=df["text"].apply(len)

# %%
df
# Out:
#       target                                               text  \
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
#       num_characters
# 0                111
# 1                 29
# 2                155
# 3                 49
# 4                 61
# ...              ...
# 5567             161
# ...

# %%
# numb of words
df['num_words']=df["text"].apply((lambda x:nltk.word_tokenize(x))).apply(len)
# Out:
# <ipython-input-22-62f50e1ca3ce>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_words']=df["text"].apply((lambda x:nltk.word_tokenize(x))).apply(len)

# %%
df
# Out:
#       target                                               text  \
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
#       num_characters  num_words
# 0                111         24
# 1                 29          8
# 2                155         37
# 3                 49         13
# ...

# %%
df['num_sent']=df["text"].apply((lambda x:nltk.sent_tokenize(x))).apply(len)
# Out:
# <ipython-input-24-40ce9fa3c9fc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_sent']=df["text"].apply((lambda x:nltk.sent_tokenize(x))).apply(len)

# %%
df
# Out:
#       target                                               text  \
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
#       num_characters  num_words  num_sent
# 0                111         24         2
# 1                 29          8         2
# 2                155         37         2
# ...

# %%
df.iloc[:,1:].describe()
# Out:
#        num_characters    num_words     num_sent
# count     5169.000000  5169.000000  5169.000000
# mean        78.977945    18.453279     1.947185
# std         58.236293    13.324793     1.362406
# min          2.000000     1.000000     1.000000
# 25%         36.000000     9.000000     1.000000
# 50%         60.000000    15.000000     1.000000
# 75%        117.000000    26.000000     2.000000
# max        910.000000   220.000000    28.000000

# %%
#ham Massage Analysis

df[df["target"]==0][["num_characters","num_words",'num_sent']].describe()


# here we are able to see that the Length of the number of Characters in  ham massage i 70 it could be an indicator 
# of the Spam or Ham
# Out:
#        num_characters    num_words     num_sent
# count     4516.000000  4516.000000  4516.000000
# mean        70.459256    17.120903     1.799601
# std         56.358207    13.493725     1.278465
# min          2.000000     1.000000     1.000000
# 25%         34.000000     8.000000     1.000000
# 50%         52.000000    13.000000     1.000000
# 75%         90.000000    22.000000     2.000000
# max        910.000000   220.000000    28.000000

# %%
#Spam Massage Analysis

df[df["target"]==1][["num_characters","num_words",'num_sent']].describe()

# here we are able to see that the Length of the number of Characters in  Sam massage i 137 it could be an indicator 
# of the Spam or Ham
# Out:
#        num_characters   num_words    num_sent
# count      653.000000  653.000000  653.000000
# mean       137.891271   27.667688    2.967841
# std         30.137753    7.008418    1.483201
# min         13.000000    2.000000    1.000000
# 25%        132.000000   25.000000    2.000000
# 50%        149.000000   29.000000    3.000000
# 75%        157.000000   32.000000    4.000000
# max        224.000000   46.000000    8.000000

# %%
plt.figure(figsize=(17,5))
sns.histplot(df[df["target"]== 0]["num_characters"],legend="")
sns.histplot(df[df["target"]== 1]["num_characters"],color="r",legend=["Spam"])

# %%
sns.kdeplot(df[df["target"]== 0]["num_characters"])
sns.kdeplot(df[df["target"]== 1]["num_characters"],color="r")

# %%
sns.pairplot(df,hue="target")

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),cmap="coolwarm",annot=True)

# %% [markdown]
# # 3 Data Preprocessing
# - Lower case
# - Tokenization
# - Removing Special characters
# - Removing stop Words and Puctuation
# - Stemming

# %%
def transform_text(text):
  text=text.lower()
  text=nltk.word_tokenize(text)
  y=[]

  for i in text:
    if i.isalnum():
      y.append(i)
  text=y[:]
  y.clear()

  for i in text:
    if i  not in stopwords.words('english') and i not in string.punctuation:
      y.append(i)
  text=y[:]
  y.clear()
  for i in text:
    y.append(ps.stem(i))

  return " ".join(y)

# %%
transform_text("is this is the Presentation that you are Talking about")
# Out:
# 'present talk'

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
import string
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()
ps.stem('Flying')
# Out:
# 'fli'

# %%
df["transformed_text"]=df["text"].apply(transform_text)
# Out:
# <ipython-input-45-bc77560020da>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["transformed_text"]=df["text"].apply(transform_text)

# %%
df
# Out:
#       target                                               text  \
# 0          0  Go until jurong point, crazy.. Available only ...
# 1          0                      Ok lar... Joking wif u oni...
# 2          1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3          0  U dun say so early hor... U c already then say...
# 4          0  Nah I don't think he goes to usf, he lives aro...
# ...      ...                                                ...
# 5567       1  This is the 2nd time we have tried 2 contact u...
# 5568       0              Will Ì_ b going to esplanade fr home?
# 5569       0  Pity, * was in mood for that. So...any other s...
# 5570       0  The guy did some bitching but I acted like i'd...
# 5571       0                         Rofl. Its true to its name
#
#       num_characters  num_words  num_sent  \
# 0                111         24         2
# 1                 29          8         2
# 2                155         37         2
# ...

# %%
from wordcloud import WordCloud
wc=WordCloud(width=500,height=500,min_font_size=10,background_color="white")

# %%
spam_wc=wc.generate(df[df["target"]== 1]["transformed_text"].str.cat(sep=' '))

# %%
plt.figure(figsize=(15,20))
plt.imshow(spam_wc)
plt.title("Most Common words in Spam Massages")
plt.show()

# %%
ham_wc=wc.generate(df[df["target"]== 0]["transformed_text"].str.cat(sep=' '))
plt.figure(figsize=(15,20))
plt.imshow(ham_wc)
plt.title("Most Common words in Not Spam Massages")
plt.show()

# %%
# this is the code for getting the most common Occuring words from scratch
spam_corpus=[]
for msg in df[df["target"]==1]["transformed_text"].tolist():
  for word in msg.split():
    spam_corpus.append(word)

# %%
spam_corpus
# Out:
# ['free',
#  'entri',
#  '2',
#  'wkli',
#  'comp',
#  'win',
#  'fa',
#  'cup',
#  'final',
#  'tkt',
#  '21st',
#  'may',
#  'text',
#  'fa',
#  '87121',
#  'receiv',
#  'entri',
#  'question',
#  'std',
#  'txt',
#  'rate',
#  'c',
#  'appli',
#  '08452810075over18',
#  'freemsg',
#  'hey',
#  'darl',
#  '3',
#  'week',
#  'word',
#  'back',
#  'like',
#  'fun',
#  'still',
#  'tb',
#  'ok',
#  'xxx',
#  'std',
#  'chg',
#  'send',
#  'rcv',
#  'winner',
#  'valu',
#  'network',
#  'custom',
#  'select',
#  'receivea',
#  'prize',
#  'reward',
#  'claim',
#  'call',
#  'claim',
#  'code',
#  'kl341',
#  'valid',
#  '12',
#  'hour',
#  'mobil',
#  '11',
#  'month',
#  'u',
#  'r',
#  'entitl',
#  'updat',
#  'latest',
#  'colour',
#  'mobil',
#  'camera',
#  'free',
#  'call',
#  'mobil',
#  'updat',
#  'co',
#  'free',
#  '08002986030',
#  'six',
#  'chanc',
#  'win',
#  'cash',
#  '100',
#  'pound',
#  'txt',
#  'csh11',
#  'send',
#  'cost',
#  '6day',
#  'tsandc',
#  'appli',
# ...

# %%
from collections import Counter
most_common_df=pd.DataFrame(Counter(spam_corpus).most_common(30))

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=most_common_df.iloc[:,0],y=most_common_df.iloc[:,1])
plt.xticks(rotation="vertical")
plt.show()

# %%
ham_corpus=[]
for msg in df[df["target"]==0]["transformed_text"].tolist():
  for word in msg.split():
   ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 35394

# %%
most_common_ham_df=pd.DataFrame(Counter(ham_corpus).most_common(30))
plt.figure(figsize=(15,10))
sns.barplot(x=most_common_ham_df.iloc[:,0],y=most_common_ham_df.iloc[:,1])
plt.xticks(rotation="vertical")
plt.show()

# %% [markdown]
# # Model building

# %%
# using the Bag of Word for Converting the Word To vectors
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv=CountVectorizer()
tfidf= TfidfVectorizer(max_features=3000)

# %%
X=tfidf.fit_transform(df["transformed_text"]).toarray()

# %%
X.shape
# Out:
# (5169, 3000)

# %%
y=df["target"].values
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb=GaussianNB()
mnb=MultinomialNB()
bnb=BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1=gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1))
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 0.8694390715667312
# [[788 108]
#  [ 27 111]]
# 0.5068493150684932

# %%
mnb.fit(X_train,y_train)
y_pred2=mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2))
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 0.9709864603481625
# [[896   0]
#  [ 30 108]]
# 1.0

# %%
bnb.fit(X_train,y_train)
y_pred3=bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3))
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 0.9835589941972921
# [[895   1]
#  [ 16 122]]
# 0.991869918699187

# %% [markdown]
# -  scence it is an Imbalacne Dataset so here the Precision Score Matter the
# -  most so for the The Precision Score is Best for  The Multinomial Nyve Base Clasfifier
# -  thats the Resion We will Take That

# %% [markdown]
# # Model improvement
#
# > Indented block

# %%
import pickle

# %%
pickle.dump(tfidf,open("vectorizer.pkl","wb"))
pickle.dump(mnb,open("model.pkl","wb"))

# %%
input_sms="Call  free text prize"
tranform_sms=transform_text(input_sms)
print(tranform_sms)
# Out:
# call free text prize

# %%
vector_input=tfidf.transform([tranform_sms])
print(vector_input)
# Out:
#   (0, 2602)	0.4968790802918049
#   (0, 2039)	0.6034600970358547
#   (0, 1085)	0.48978052509943665
#   (0, 533)	0.3860856486418098

# %%
result=mnb.predict(vector_input)
print(result)
# Out:
# [1]
